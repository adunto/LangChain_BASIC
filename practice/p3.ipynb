# %%
import os
import json
from langchain_community.document_loaders import PyPDFLoader
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %%
from dotenv import load_dotenv
load_dotenv()
OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")

# %%
# PDF 파일 경로 설정
pdf_filepath = './data/콘텐츠분쟁해결_사례.pdf'
# 파일 존재 여부 확인 (파일이 없으면 오류 발생)
if not os.path.exists(pdf_filepath):
    raise FileNotFoundError(f"파일을 찾을 수 없습니다: {pdf_filepath}")

# %%
# PDF 파일 로드
loader = PyPDFLoader(pdf_filepath)
docs = loader.load()

# %%
# 1단계: 문서 분할 설정
pythontext_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,        #  법률 사례는 1200-1800자 권장
    chunk_overlap=300,      #  사례 맥락 보존을 위해 200-400자
    separators=[
        "\n【사건개요】",     #  법률 문서 섹션 구분자
        "\n【쟁점사항】",     #  쟁점 부분 구분
        "\n【처리경위】",     #  처리 과정 구분
        "\n【처리결과】",     #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)

# %%
chunks = pythontext_splitter.split_documents(docs)
print(chunks)
# Out:
# [Document(metadata={'producer': 'Hancom PDF 1.3.0.410', 'creator': 'Hancom PDF 1.3.0.410', 'creationdate': '2011-01-20T18:01:33+09:00', 'title': '제 2절 영국사례', 'moddate': '2011-01-20T18:01:33+09:00', 'pdfversion': '1.4', 'source': './data/콘텐츠분쟁해결_사례.pdf', 'total_pages': 109, 'page': 1, 'page_label': '2'}, page_content='콘텐츠분쟁조정 법리 연구 2부- 타 분쟁조정사례 조사 -'), Document(metadata={'producer': 'Hancom PDF 1.3.0.410', 'creator': 'Hancom PDF 1.3.0.410', 'creationdate': '2011-01-20T18:01:33+09:00', 'title': '제 2절 영국사례', 'moddate': '2011-01-20T18:01:33+09:00', 'pdfversion': '1.4', 'source': './data/콘텐츠분쟁해결_사례.pdf', 'total_pages': 109, 'page': 2, 'page_label': '3'}, page_content='차  례      콘텐츠분쟁조정 법리 연구 제2부 - 타 분쟁조정사례 조사 -타 분쟁조정 위원회 콘텐츠 분쟁해결 사례이지현(드림와이즈) 1. 게임····································································································1가'), Document(metadata={'producer': 'Hancom PDF 1.3.0.410', 'creator': 'Hancom PDF 1.3.0.410', 'creationdate': '2011-01-20T18:01:33+09:00', 'title': '제 2절 영국사례', 'moddate': '2011-01-20T18:01:33+09:00', 'pdfversion': '1.4', 'source': './data/콘텐츠분쟁해결_사례.pdf', 'total_pages': 109, 'page': 2, 'page_label': '3'}, page_content='. 한국소비자원1) 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구··················································32006_프로그램 오류로 소멸된 아이템 복구 요구··············································42007_인터넷게임서비스 아이템 복구 요구·························································52007_계정 도용 상태에서 발생한 영구이용 제한조치 취소 요구······················72007_미성년자가 타인의 사술에 의해 부당하게 결제한 요금 환급 요구··········92007_이용하지 않은 인터넷게임서비스 이용료 환급 요구·······························1 02008_불법프로그램 사용하였다며 영구이용 제한조치 한 계정 취소 요구·······1 12008_일방적으로 접속이 중지된 온라인 게임 배상 요구································1 22008_보안서비스 미작동으로 인한 아이템 도난 배상 요구·····························1 32008_신용카드결제 후 환급불가한 인터넷 게임 잔여 캐시의 환급 요구········1 42008_명의도용으로 개설된 인터넷 게임 계정 삭제 요구································1 52008_해킹으로 소실된 아이템 복원 요구························································1 62008_사용하지 못한 게임머니 구입가의 환급 요구·········································1 72008_인터넷게임서비스 잔여 이용료 환급 요구··············································1 82009_인터넷 게임 계정 영구이용 제한조치 취소 요구····································1 92009_사용하지 않았으나 차감된 아이템 배상 요구·········································2 02009_불법프로그램 사용이유로 영구 계정이용제한 조치에 대한 취소 요구···2 12009_일방적으로 이용이 정지된 온라인 게임의 복구 요청·····························2 22009_시스템 오류로 인한 손실 아이템 복구 요구··········································2 32009_명의 도용되어 부당 지급된 게임요금의 환급 요구································2 42009_해킹으로 손실된 아이템 복구 요청························································2 52009_게임서비스 사용계약 해지에 따른 아이템 환불 요구·····························2 6'), Document(metadata={'producer': 'Hancom PDF 1.3.0.410', 'creator': 'Hancom PDF 1.3.0.410', 'creationdate': '2011-01-20T18:01:33+09:00', 'title': '제 2절 영국사례', 'moddate': '2011-01-20T18:01:33+09:00', 'pdfversion': '1.4', 'source': './data/콘텐츠분쟁해결_사례.pdf', 'total_pages': 109, 'page': 3, 'page_label': '4'}, page_content='차  례      콘텐츠분쟁조정 법리 연구 제2부 - 타 분쟁조정사례 조사 - 2009_사용하지 못한 게임머니의 환급 요구·····················································2 72008_인터넷 게임 계정 영구이용 제한조치 취소 요구····································2 82) 조정결정례2007_인터넷게임서비스 계정 영구 이용제한 취소 요구··································3 02009_‘리니지’게임 계정 이용정지 사건에 대한 집단분쟁조정·························3 2나. 전자거래분쟁조정위원회2006_사이트 이용 영구정지 처분 철회 청구···················································3 62006_온라인 게임의 버그 이용 사유로 계정정지············································3 72006_미성년자 단독으로 한 결제 취소 청구···················································3 82006_게임계정 영구 압류조치 해제 청구························································3 92007_게임 계정 삭제에 대한 원상 복귀 요청·················································4 12008_온라인게임 해지로 인한 서비스 이용요금 환불의 건·····························4 32008_부당결제대금 반환 청구·········································································4 52008_미성년자의 신용카드 부정사용에 따른 매매대금 반환 신청···················4 72. 이러닝····························································· ...

# %%
# 2단계: 임베딩 모델 설정 
pythonembeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  #  한국어 법률 용어에 최적
    dimensions=1536                  #  고성능 임베딩 차원
)

# %%
# 벡터 저장
vectorstore = FAISS.from_documents(chunks, pythonembeddings)

# %%
# 3단계: 검색기 설정 
pythonretriever = vectorstore.as_retriever(
    search_type="similarity",        #  또는 "mmr" (다양성 고려시)
    search_kwargs={"k": 5}          #  상위 5개 관련 사례 검색
)

# %%
# 4단계: LLM 설정 
pythonllm = ChatOpenAI(
    model="gpt-4o",                 #  또는 "gpt-4o-mini" (경제적)
    temperature=0.2,                #  법률 조언은 정확성 중시
    max_tokens=2000                 #  충분한 답변 길이
)

# %%
# 5단계: 법률 자문 프롬프트 작성 
pythonprompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정

전문 법률 조언:"""

# %%
# 6단계: QA 체인 생성 
pythonqa_chain = RetrievalQA.from_chain_type(
    llm=pythonllm,                  #  위에서 설정한 LLM
    chain_type="stuff",             #  문서들을 하나로 합쳐서 처리
    retriever=pythonretriever,      #  위에서 설정한 검색기
    chain_type_kwargs={
        "prompt": PromptTemplate(
            template=pythonprompt_template,
            input_variables=["context", "question"]
        )
    },  #  법률 자문 프롬프트
    return_source_documents=True    #  참조 문서도 함께 반환
)

# %%
# 7단계: 테스트 질문 작성 
pythontest_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

# %%
for i, q in enumerate(pythontest_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {q}")
    print(" 답변 생성 중...")
    
    result = pythonqa_chain.invoke({"query": q})
    answer = result["result"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
# Out:
# 【테스트 1/5】
#  질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률 조언을 드리겠습니다. 제시된 사례들을 바탕으로 답변을 구성하겠습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례 1-가-1) 2006년 사례에서는 시스템 오류로 인해 아이템이 소멸된 경우, 계정 명의자가 아니면 복구 처리가 불가하다는 결론이 있었습니다. 계정 명의자가 직접 복구 신청을 해야 한다는 점이 강조되었습니다.
#    - 2009년 사례에서는 시스템 오류로 인한 손실이 주장되었으나, 다른 사용자들에게 유사한 불만이 접수되지 않았고, 사용 내역 상 큰 문제가 없다는 이유로 시스템 오류로 보기 어렵다는 결론이 내려졌습니다.
#
# 2. **법적 근거 제시**:
#    - 게임사의 약관에 따라 계정 명의자만이 복구 요청을 할 수 있다는 규정이 있을 수 있습니다. 따라서 약관을 확인하고, 계정 명의자가 복구 요청을 할 수 있도록 해야 합니다.
#
# 3. **판례 참조**:
#    - 앞서 언급한 사례들에서 볼 수 있듯이, 시스템 오류로 인한 손실에 대한 복구는 게임사의 약관과 정책에 따라 다르게 처리될 수 있습니다. 특히, 계정 명의자 여부와 시스템 오류의 입증 여부가 중요한 쟁점이 됩니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 게임사의 약관을 확인하여 복구 요청 절차와 계정 명의자 요건을 파악합니다.
#    - **2단계**: 계정 명의자가 복구 요청을 직접 할 수 있도록 조치합니다.
#    - **3단계**: 시스템 오류로 인한 손실임을 입증할 수 있는 증거(예: 오류 발생 시점의 스크린샷, 로그 기록 등)를 수집합니다.
#    - **4단계**: 게임사에 공식적으로 복구 요청을 제출하고, 필요시 한국소비자원 등 관련 기관에 중재를 요청합니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정한 법령이나 조항에 대한 언급이 없으므로, 관련 법령에 대한 구체적인 정보는 확인할 수 없습니다.
#
# 이러한 단계들을 통해 문제를 해결할 수 있도록 노력하시기 바랍니다. 추가적인 법적 조언이 필요하다면, 전문 변호사와 상담하는 것도 고려해보세요.
#
# 【테스트 2/5】
#  질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 인터넷 강의를 중도 해지하려는 상황에서 과도한 위약금을 요구받고 있는 경우, 다음과 같은 법률 조언을 드립니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 공통적으로 다루어진 쟁점은 계약 해지 시 위약금의 적정성입니다. 예를 들어, 2007년 사례에서는 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제 후 환급하도록 규정되어 있습니다.
#    - 2010년 사례에서도 해지일까지의 이용일수에 해당하는 금액과 위약금 10%를 공제한 후 환급하는 것이 적정하다고 판단되었습니다.
#
# 2. **법적 근거 제시**:
#    - 방문판매 등에 관한 법률 제29조(계약의 해지)와 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)을 참고할 수 있습니다. 이 법령들은 계약 해지 시 위약금의 적정성을 판단하는 기준을 제공합니다.
#
# 3. **판례 참조**:
#    - 2010년 화상불량 사례에서는 계약 해지의 귀책사유가 양 당사자 중 어디에 귀속되는지를 판단하여, 실제 이용일수를 기준으로 환급하도록 결정되었습니다.
#    - 2008년 온라인 동영상 강의 사례에서는 청약철회 기간을 경과한 경우에도 이용일수와 총 이용금액의 10%를 공제한 후 환급하는 것이 적정하다고 판단되었습니다.
#
# 4. **실무 가이드**:
#    - **계약서 검토**: 먼저, 계약서에 명시된 환불 및 위약금 조항을 면밀히 검토하세요. 계약서에 명시된 내용이 법령과 소비자분쟁해결기준에 부합하는지 확인합니다.
#    - **이용일수 계산**: 실제로 강의를 이용한 일수를 계산하여, 해당 일수에 대한 비용을 산정합니다.
#    - **위약금 확인**: 총 이용금액의 10%를 초과하는 위약금을 요구받았다면, 이는 과도할 수 있으므로 이의를 제기할 수 있습니다.
#    - **소비자원 상담**: 한국소비자원이나 전자거래분쟁조정위원회에 상담을 요청하여 중재를 받을 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정한 상황에 대한 모든 세부사항을 확인할 수 없으므로, 구체적인 계약 내용이나 상황에 따라 결과가 달라질 수 있습니다.
#
# 이러한 조언을 바탕으로, 계약 해지 및 환불 절차를 진행하시기 바랍니다. 추가적인 법적 조언이 필요하다면, 전문 변호사와 상담하는 것도 고려해 보세요.
#
# 【테스트 3/5】
#  질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 무료체험 후 자동으로 유료 전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언은 다음과 같습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 공통적으로 나타나는 문제는 무료 체험 후 자동 유료 전환에 대한 고지가 명확하지 않거나, 소비자가 쉽게 인지할 수 없는 방식으로 이루어졌다는 점입니다. 이러한 경우, 소비자는 계약의 중요 내용을 충분히 인지하지 못한 상태에서 유료 서비스에 가입하게 된 것이므로, 환불을 요구할 수 있는 근거가 될 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - 「약관의 규제에 관한 법률」 제3조는 약관의 작성 및 설명의무를 규정하고 있으며, 소비자가 계약의 중요 내용을 명확히 인지할 수 있도록 해야 합니다.
#    - 「소비자기본법」에 따른 소비자분쟁해결기준(공정위 고시)도 소비자에게 불리한 약관 조항을 제한하고 있습니다.
#
# 3. **판례 참조**:
#    - 제시된 사례들에서는 소비자가 무료 체험 후 자동 유료 전환에 대해 충분히 고지받지 못한 경우, 환불이 이루어졌습니다. 특히, 고지 내용이 작거나 명확하지 않은 경우, 소비자에게 환불 조치가 권고되었습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 서비스 제공자에게 무료 체험 후 자동 유료 전환에 대한 고지가 명확히 이루어졌는지 확인합니다. 특히, 고지 내용이 소비자가 쉽게 인지할 수 있는 방식으로 제공되었는지 검토합니다.
#    - **2단계**: 서비스 제공자에게 환불을 요청합니다. 이때, 무료 체험 후 유료 전환에 대한 고지가 명확하지 않았음을 강조합니다.
#    - **3단계**: 서비스 제공자가 환불을 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 분쟁 조정을 신청합니다.
#    - **4단계**: 필요시, 법률 전문가의 도움을 받아 소송을 고려할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정 서비스나 계약의 세부 사항에 대한 정보는 확인할 수 없습니다. 따라서, 개별 계약의 구체적인 내용에 따라 결과가 달라질 수 있음을 유의해야 합니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 조치를 취하시기 바랍니다.
#
# 【테스트 4/5】
#  질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 환불을 받을 수 있는 가능성은 여러 법적 요소에 따라 달라질 수 있습니다. 아래에 제시된 사례들을 근거로 하여 관련 법령과 판례를 참고하여 답변을 드리겠습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서는 미성년자가 부모의 동의 없이 타인의 명의를 도용하거나 부모의 신용카드를 사용하여 결제를 진행한 경우가 있었습니다. 이러한 경우, 미성년자의 행위는 원칙적으로 취소가 가능하지만, 미성년자가 사술을 사용하여 자신이 능력자임을 적극적으로 표시한 경우에는 취소가 어려울 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - **민법 제5조**: 미성년자의 능력에 관한 규정으로, 미성년자는 법정대리인의 동의 없이 법률행위를 할 수 없습니다.
#    - **민법 제17조**: 무능력자의 사술에 관한 규정으로, 미성년자가 사술로써 능력자임을 믿게 한 경우에는 취소할 수 없습니다.
#    - **민법 제741조**: 부당이득의 내용으로, 계약 없이 결제를 받았다면 이는 부당이득으로 반환의 대상이 됩니다.
#
# 3. **판례 참조**:
#    - 대법원 판례(1971. 12. 14. 선고 71다2045)에서는 미성년자가 사술을 사용하여 능력자임을 믿게 한 경우 취소할 수 없다고 판시하였습니다. 따라서, 미성년자가 적극적으로 사술을 사용한 경우에는 계약 취소가 어렵습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 미성년자의 구매 행위가 법정대리인의 동의 없이 이루어졌는지 확인합니다.
#    - **2단계**: 미성년자가 사술을 사용하여 능력자임을 표시했는지 여부를 검토합니다. 예를 들어, 타인의 명의를 도용하거나 부모의 신용카드를 사용한 경우가 이에 해당할 수 있습니다.
#    - **3단계**: 해당 게임사와의 협의를 통해 환불 가능성을 타진합니다. 게임머니를 반환할 경우 환불이 가능할 수 있습니다.
#    - **4단계**: 법적 조치를 고려할 경우, 변호사와 상담하여 구체적인 법적 대응 방안을 마련합니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정한 상황에 대한 모든 가능성을 다루고 있지 않으므로, 추가적인 사례나 법적 해석이 필요할 수 있습니다.
#
# 이와 같은 절차를 통해 미성년자의 부당한 결제에 대한 환불 가능성을 검토할 수 있습니다. 추가적인 법적 조언이 필요하다면 전문 변호사와 상담하시기를 권장합니다.
#
# 【테스트 5/5】
#  질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶으시다면, 다음과 같은 법률적 조언을 드릴 수 있습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서는 온라인 교육 서비스 계약 해지와 관련된 다양한 분쟁이 있었습니다. 특히, 계약 해지 및 환불과 관련된 분쟁이 자주 발생하며, 각 사례에서는 계약 해지의 적법성 및 환불 금액 산정 기준이 주요 쟁점이었습니다.
#
# 2. **법적 근거 제시**:
#    - **방문판매 등에 관한 법률** 제29조와 제30조는 계약의 해지 및 해지 또는 해제의 효과와 위약금에 대해 규정하고 있습니다. 이 법률에 따르면, 소비자는 계약을 해지할 수 있으며, 해지로 인해 발생하는 손실을 현저하게 초과하는 위약금을 청구할 수 없습니다.
#    - **소비자기본법에 따른 소비자분쟁해결기준**은 인터넷 콘텐츠 업종에서의 분쟁 해결 기준을 제시하고 있습니다.
#
# 3. **판례 참조**:
#    - 2008년 사례에서는 신청인이 강의를 수강하지 않았음에도 불구하고 청약철회 기간을 경과했다는 이유로 환불이 거부되었습니다. 그러나 분쟁조정위원회는 상호 양보를 통해 환불을 조정하였습니다.
#    - 2010년 사례에서는 계약 해지 후 피신청인이 총 이용요금의 2/3를 공제하려 했으나, 계약기간의 1/12도 경과하지 않았다는 이유로 받아들여지지 않았습니다.
#
# 4. **실무 가이드**:
#    - **계약서 검토**: 먼저, 계약서에 명시된 해지 및 환불 조건을 확인하세요. 광고와 실제 제공된 서비스가 다르다면, 이를 증명할 수 있는 자료를 준비하세요.
#    - **해지 의사 표시**: 계약 해지를 원하신다면, 서면으로 해지 의사를 명확히 표시하고 기록을 남기세요.
#    - **분쟁조정 신청**: 사업자가 환불을 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 분쟁조정을 신청할 수 있습니다.
#    - **법적 조치 고려**: 필요시 법률 전문가와 상담하여 법적 조치를 고려할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 광고와 실제 제공된 서비스의 차이에 따른 계약 해지 사례는 확인할 수 없습니다. 그러나 일반적인 계약 해지 및 환불 절차에 따라 대응할 수 있습니다.
#
# 이러한 조언을 바탕으로, 계약 해지 및 환불 절차를 진행하시길 바랍니다. 추가적인 법률적 조언이 필요하시다면, 전문 변호사와 상담하시기를 권장합니다.

# %%
# 8단계: 분쟁 유형 분류 함수 ( 선택 )
def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"

# %%
for i, q in enumerate(pythontest_questions, 1):
    result = classify_dispute_type(q)
    print(result)
# Out:
# 게임
# 이러닝
# 이러닝
# 게임
# None
